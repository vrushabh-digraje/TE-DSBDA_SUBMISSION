# %% [markdown]
# Name : Aditya A. Ramteke
# Roll_No: 53

# %% [markdown]
# Lab_Practical_1

# %% [markdown]
# 1. Import all the required Python libraries

# %%
import pandas as pd

# %% [markdown]
# 2. Load the dataset into Pandas dataframe

# %%
df = pd.read_csv('pokemon_data_pokeapi.csv')

# %%
df
# Out:
#                    Name  Pokedex Number     Type1   Type2  Classification  \
# 0             Bulbasaur               1     Grass  Poison    Seed Pokémon
# 1               Ivysaur               2     Grass  Poison    Seed Pokémon
# 2              Venusaur               3     Grass  Poison    Seed Pokémon
# 3            Charmander               4      Fire     NaN  Lizard Pokémon
# 4            Charmeleon               5      Fire     NaN   Flame Pokémon
# ..                  ...             ...       ...     ...             ...
# 900            Ursaluna             901    Ground  Normal        でいたんポケモン
# 901    Basculegion-male             902     Water   Ghost        おおうおポケモン
# 902            Sneasler             903  Fighting  Poison      クライミングポケモン
# 903            Overqwil             904      Dark  Poison        けんざんポケモン
# 904  Enamorus-incarnate             905     Fairy  Flying        あいぞうポケモン
#
#      Height (m)  Weight (kg)                               Abilities  \
# ...

# %% [markdown]
# 3. Fetch different records to check Dataframe loaded successfully

# %%
df.head()
# Out:
#          Name  Pokedex Number  Type1   Type2  Classification  Height (m)  \
# 0   Bulbasaur               1  Grass  Poison    Seed Pokémon         0.7
# 1     Ivysaur               2  Grass  Poison    Seed Pokémon         1.0
# 2    Venusaur               3  Grass  Poison    Seed Pokémon         2.0
# 3  Charmander               4   Fire     NaN  Lizard Pokémon         0.6
# 4  Charmeleon               5   Fire     NaN   Flame Pokémon         1.1
#
#    Weight (kg)              Abilities  Generation Legendary Status
# 0          6.9  Overgrow, Chlorophyll           1               No
# 1         13.0  Overgrow, Chlorophyll           1               No
# 2        100.0  Overgrow, Chlorophyll           1               No
# 3          8.5     Blaze, Solar-power           1               No
# 4         19.0     Blaze, Solar-power           1               No

# %%
df.tail()
# Out:
#                    Name  Pokedex Number     Type1   Type2 Classification  \
# 900            Ursaluna             901    Ground  Normal       でいたんポケモン
# 901    Basculegion-male             902     Water   Ghost       おおうおポケモン
# 902            Sneasler             903  Fighting  Poison     クライミングポケモン
# 903            Overqwil             904      Dark  Poison       けんざんポケモン
# 904  Enamorus-incarnate             905     Fairy  Flying       あいぞうポケモン
#
#      Height (m)  Weight (kg)                               Abilities  \
# 900         2.4        290.0              Guts, Bulletproof, Unnerve
# 901         3.0        110.0  Swift-swim, Adaptability, Mold-breaker
# 902         1.3         43.0        Pressure, Unburden, Poison-touch
# 903         2.5         60.5    Poison-point, Swift-swim, Intimidate
# 904         1.6         48.0                    Cute-charm, Contrary
#
#      Generation Legendary Status
# 900           8               No
# 901           8               No
# ...

# %% [markdown]
# 4. Check structure of the dataset.

# %%
df.shape
# Out:
# (905, 10)

# %%
df.size
# Out:
# 9050

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# 5. Check Attribute of Dataframe

# %%
df.columns
# Out:
# Index(['Name', 'Pokedex Number', 'Type1', 'Type2', 'Classification',
#        'Height (m)', 'Weight (kg)', 'Abilities', 'Generation',
#        'Legendary Status'],
#       dtype='object')

# %% [markdown]
# 6. Check the data types of columns in Dataframe

# %%
df.dtypes
# Out:
# Name                 object
# Pokedex Number        int64
# Type1                object
# Type2                object
# Classification       object
# Height (m)          float64
# Weight (kg)         float64
# Abilities            object
# Generation            int64
# Legendary Status     object
# dtype: object

# %% [markdown]
# 7. Check Attribute information of Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              905 non-null    object
#  1   Pokedex Number    905 non-null    int64
#  2   Type1             905 non-null    object
#  3   Type2             449 non-null    object
#  4   Classification    905 non-null    object
#  5   Height (m)        905 non-null    float64
#  6   Weight (kg)       905 non-null    float64
#  7   Abilities         905 non-null    object
#  8   Generation        905 non-null    int64
#  9   Legendary Status  905 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 70.8+ KB

# %% [markdown]
# 8. Check description of Dataframe

# %%
df.describe()
# Out:
#        Pokedex Number  Height (m)  Weight (kg)  Generation
# count      905.000000  905.000000   905.000000  905.000000
# mean       453.000000    1.192707    64.288066    4.176796
# std        261.395295    1.232754   119.224378    2.264997
# min          1.000000    0.100000     0.100000    1.000000
# 25%        227.000000    0.500000     8.500000    2.000000
# 50%        453.000000    1.000000    28.000000    4.000000
# 75%        679.000000    1.500000    65.500000    6.000000
# max        905.000000   20.000000   999.900000    8.000000

# %% [markdown]
# 9. Check null values of Dataframe

# %%
df.isna()
# Out:
#       Name  Pokedex Number  Type1  Type2  Classification  Height (m)  \
# 0    False           False  False  False           False       False
# 1    False           False  False  False           False       False
# 2    False           False  False  False           False       False
# 3    False           False  False   True           False       False
# 4    False           False  False   True           False       False
# ..     ...             ...    ...    ...             ...         ...
# 900  False           False  False  False           False       False
# 901  False           False  False  False           False       False
# 902  False           False  False  False           False       False
# 903  False           False  False  False           False       False
# 904  False           False  False  False           False       False
#
#      Weight (kg)  Abilities  Generation  Legendary Status
# 0          False      False       False             False
# ...

# %%
df.isnull().any()
# Out:
# Name                False
# Pokedex Number      False
# Type1               False
# Type2                True
# Classification      False
# Height (m)          False
# Weight (kg)         False
# Abilities           False
# Generation          False
# Legendary Status    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name                  0
# Pokedex Number        0
# Type1                 0
# Type2               456
# Classification        0
# Height (m)            0
# Weight (kg)           0
# Abilities             0
# Generation            0
# Legendary Status      0
# dtype: int64
