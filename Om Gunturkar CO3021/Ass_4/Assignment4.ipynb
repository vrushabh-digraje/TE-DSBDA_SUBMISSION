# %%
import pandas as pd

# %%
df= pd.read_csv("ass_4_updated.csv")

# %%
df
# Out:
#     Unnamed: 0  YearsExperience  Salary
# 0            0              2.0   39344
# 1            1              3.0   46206
# 2            2              1.6   55795
# 3            3              5.0   43526
# 4            4              2.3   39892
# 5            5              7.0   11231
# 6            6              3.0   60151
# 7            7              3.3   43545
# 8            8              3.0   34234
# 9            9              3.8   57190
# 10          10              4.0   63219
# 11          11              4.1   55795
# 12          12              2.0   56958
# 13          13              4.2   57082
# 14          14              4.0   61112
# 15          15              5.0   60151
# 16          16              6.0   56456
# 17          17              5.4   83089
# 18          18              2.0   81364
# 19          19              6.1   93941
# 20          20              7.0   47567
# 21          21              7.2   98274
# 22          22             14.0  101303
# 23          23              8.3   32453
# 24          24              3.0   56878
# 25          25              9.1  105583
# 26          26             22.0  116970
# 27          27              9.7  567522
# 28          28              9.0  122392
# 29          29             15.0   56785
# 30          30              3.0   34234
# 31          31              7.0   47567
# 32          32              8.3   32453
# 33          33              9.0  122392
# 34          34              5.0   60151

# %%
df.shape[0]
# Out:
# 35

# %%
df.shape[1]
# Out:
# 3

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   35.000000        35.000000      35.000000
# mean    17.000000         6.097143   77223.000000
# std     10.246951         4.247455   89577.362533
# min      0.000000         1.600000   11231.000000
# 25%      8.500000         3.000000   44875.500000
# 50%     17.000000         5.000000   56958.000000
# 75%     25.500000         7.750000   82226.500000
# max     34.000000        22.000000  567522.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       35 non-null     int64
#  1   YearsExperience  35 non-null     float64
#  2   Salary           35 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 972.0 bytes

# %%
df.isnull()
# Out:
#     Unnamed: 0  YearsExperience  Salary
# 0        False            False   False
# 1        False            False   False
# 2        False            False   False
# 3        False            False   False
# 4        False            False   False
# 5        False            False   False
# 6        False            False   False
# 7        False            False   False
# 8        False            False   False
# 9        False            False   False
# 10       False            False   False
# 11       False            False   False
# 12       False            False   False
# 13       False            False   False
# 14       False            False   False
# 15       False            False   False
# 16       False            False   False
# 17       False            False   False
# 18       False            False   False
# 19       False            False   False
# 20       False            False   False
# 21       False            False   False
# 22       False            False   False
# 23       False            False   False
# 24       False            False   False
# 25       False            False   False
# 26       False            False   False
# 27       False            False   False
# 28       False            False   False
# 29       False            False   False
# 30       False            False   False
# 31       False            False   False
# 32       False            False   False
# 33       False            False   False
# 34       False            False   False

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience  Salary
# 0           0              2.0   39344
# 1           1              3.0   46206
# 2           2              1.6   55795
# 3           3              5.0   43526
# 4           4              2.3   39892

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience  Salary
# 30          30              3.0   34234
# 31          31              7.0   47567
# 32          32              8.3   32453
# 33          33              9.0  122392
# 34          34              5.0   60151

# %%
df.count()
# Out:
# Unnamed: 0         35
# YearsExperience    35
# Salary             35
# dtype: int64

# %%
#---------------------------LINEAR REGRESSION-------------------------------------------------

# %%
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Salary'], kde=True, bins=30, color='blue')
plt.title("Salary ")
plt.xlabel("Salary")
plt.ylabel("experiencxe")
plt.show()

# %%
#------------------------------------TESTING AND TRAINING ----------------------------------------

# %%
y = df['Salary']
X = df[['YearsExperience']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((24, 1), (11, 1), (24,), (11,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 78110.8180309 , 150176.04248849,  90121.68877383,  60094.5119165 ,
#         60094.5119165 ,  83365.57398093,  90121.68877383,  54839.75596647,
#         75108.10034517,  52587.71770217,  49585.00001644])

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 28665.38095003287

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.5661488895974768

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1402679241.3390524

# %%
#------------------------------------------------OTHER TASK ON LINEAR REGRESSION--------------------------------------
