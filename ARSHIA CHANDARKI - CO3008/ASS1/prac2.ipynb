# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dt.csv")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  Name  projects-done  Tech ID                  Role  \
# 0    Arshia Chandarki            2.0      1.0       Project Manager
# 1     Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2         Ayesha Khan            2.0      3.0        UI/UX Designer
# 3       Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4     Sakshi Chudekar            2.0      5.0       Project Manager
# 5      Shrawani Botre            2.0      NaN     Backend Developer
# 6         Ketan Butta            2.0      7.0     Backend Developer
# 7       Tanmay Shinde            2.0      8.0        UI/UX Designer
# 8       Jannat Shaikh            2.0      9.0     Backend Developer
# 9       Tauhid Shaikh            2.0     10.0           AI Engineer
# 10      Pratik Palkar            2.0     11.0  Cybersecurity Intern
# 11  Kruthika Janvekar            2.0     12.0           AI Engineer
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                  Name  projects-done  Tech ID                  Role  \
# 0    Arshia Chandarki            2.0      1.0       Project Manager
# 1     Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2         Ayesha Khan            2.0      3.0        UI/UX Designer
# 3       Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4     Sakshi Chudekar            2.0      5.0       Project Manager
# 5      Shrawani Botre            2.0      NaN     Backend Developer
# 6         Ketan Butta            2.0      7.0     Backend Developer
# 7       Tanmay Shinde            2.0      8.0        UI/UX Designer
# 8       Jannat Shaikh            2.0      9.0     Backend Developer
# 9       Tauhid Shaikh            2.0     10.0           AI Engineer
# 10      Pratik Palkar            2.0     11.0  Cybersecurity Intern
# 11  Kruthika Janvekar            2.0     12.0           AI Engineer
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Name  projects-done  Tech ID                  Role  \
# 0    Arshia Chandarki            2.0      1.0       Project Manager
# 1     Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2         Ayesha Khan            2.0      3.0        UI/UX Designer
# 3       Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4     Sakshi Chudekar            2.0      5.0       Project Manager
# 5      Shrawani Botre            2.0      NaN     Backend Developer
# 6         Ketan Butta            2.0      7.0     Backend Developer
# 7       Tanmay Shinde            2.0      8.0        UI/UX Designer
# 8       Jannat Shaikh            2.0      9.0     Backend Developer
# 9       Tauhid Shaikh            2.0     10.0           AI Engineer
# 10      Pratik Palkar            2.0     11.0  Cybersecurity Intern
# 11  Kruthika Janvekar            2.0     12.0           AI Engineer
# ...

# %%
df.columns
# Out:
# Index(['Name', 'projects-done', 'Tech ID', 'Role', 'Project Worked On'], dtype='object')

# %%
df.describe()
# Out:
#        projects-done    Tech ID
# count           29.0  28.000000
# mean             2.0  15.928571
# std              0.0   8.914942
# min              2.0   1.000000
# 25%              2.0   8.750000
# 50%              2.0  16.500000
# 75%              2.0  23.250000
# max              2.0  30.000000

# %%
print(' rows present:',df.shape[0])
print(' columns present:',df.shape[1])
# Out:
#  rows present: 30
#  columns present: 5

# %%
print (' the total is' ,df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               30 non-null     object
#  1   projects-done      29 non-null     float64
#  2   Tech ID            28 non-null     float64
#  3   Role               30 non-null     object
#  4   Project Worked On  25 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 1.3+ KB
#  the total is None

# %%
df.iloc[:8] # index loc means starts by index
# Out:
#                Name  projects-done  Tech ID                  Role  \
# 0  Arshia Chandarki            2.0      1.0       Project Manager
# 1   Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2       Ayesha Khan            2.0      3.0        UI/UX Designer
# 3     Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5    Shrawani Botre            2.0      NaN     Backend Developer
# 6       Ketan Butta            2.0      7.0     Backend Developer
# 7     Tanmay Shinde            2.0      8.0        UI/UX Designer
#
#           Project Worked On
# 0  Smart Traffic Management
# 1    Cybersecurity Research
# 2              Online Store
# 3       Technologia Website
# 4                       NaN
# 5   IoT Women Safety Device
# 6   IoT Women Safety Device
# 7       Technologia Website

# %%
df.tail(1)
# Out:
#           Name  projects-done  Tech ID               Role Project Worked On
# 29  Nihal Josh            2.0     30.0  Backend Developer      Online Store

# %%
print('Total number of rows:',df.shape[0],'\nTotal number of columns:',df.shape[1])
# Out:
# Total number of rows: 30
# Total number of columns: 5

# %%
df.isnull()
# Out:
#      Name  projects-done  Tech ID   Role  Project Worked On
# 0   False          False    False  False              False
# 1   False          False    False  False              False
# 2   False          False    False  False              False
# 3   False          False    False  False              False
# 4   False          False    False  False               True
# 5   False          False     True  False              False
# 6   False          False    False  False              False
# 7   False          False    False  False              False
# 8   False          False    False  False              False
# 9   False          False    False  False              False
# 10  False          False    False  False              False
# 11  False          False    False  False               True
# 12  False          False     True  False              False
# 13  False          False    False  False              False
# 14  False          False    False  False              False
# ...

# %%
df.isna().sum()  #yto count null
# Out:
# Name                 0
# projects-done        1
# Tech ID              2
# Role                 0
# Project Worked On    5
# dtype: int64

# %%
df.bfill()
# Out:
#                  Name  projects-done  Tech ID                  Role  \
# 0    Arshia Chandarki            2.0      1.0       Project Manager
# 1     Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2         Ayesha Khan            2.0      3.0        UI/UX Designer
# 3       Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4     Sakshi Chudekar            2.0      5.0       Project Manager
# 5      Shrawani Botre            2.0      7.0     Backend Developer
# 6         Ketan Butta            2.0      7.0     Backend Developer
# 7       Tanmay Shinde            2.0      8.0        UI/UX Designer
# 8       Jannat Shaikh            2.0      9.0     Backend Developer
# 9       Tauhid Shaikh            2.0     10.0           AI Engineer
# 10      Pratik Palkar            2.0     11.0  Cybersecurity Intern
# 11  Kruthika Janvekar            2.0     12.0           AI Engineer
# 12        Prerna Shah            2.0     14.0         Web Developer
# ...

# %%
 df.ffill()
# Out:
#                  Name  projects-done  Tech ID                  Role  \
# 0    Arshia Chandarki            2.0      1.0       Project Manager
# 1     Nazia Chandarki            2.0      2.0        UI/UX Designer
# 2         Ayesha Khan            2.0      3.0        UI/UX Designer
# 3       Ayushi Gautam            2.0      4.0  Cybersecurity Intern
# 4     Sakshi Chudekar            2.0      5.0       Project Manager
# 5      Shrawani Botre            2.0      5.0     Backend Developer
# 6         Ketan Butta            2.0      7.0     Backend Developer
# 7       Tanmay Shinde            2.0      8.0        UI/UX Designer
# 8       Jannat Shaikh            2.0      9.0     Backend Developer
# 9       Tauhid Shaikh            2.0     10.0           AI Engineer
# 10      Pratik Palkar            2.0     11.0  Cybersecurity Intern
# 11  Kruthika Janvekar            2.0     12.0           AI Engineer
# 12        Prerna Shah            2.0     12.0         Web Developer
# ...

# %%
x= df["Tech ID"].mean()

# %%
x
# Out:
# np.float64(15.928571428571429)

# %%
df["Tech ID"].fillna(x)
# Out:
# 0      1.000000
# 1      2.000000
# 2      3.000000
# 3      4.000000
# 4      5.000000
# 5     15.928571
# 6      7.000000
# 7      8.000000
# 8      9.000000
# 9     10.000000
# 10    11.000000
# 11    12.000000
# 12    15.928571
# 13    14.000000
# 14    15.000000
# 15    16.000000
# 16    17.000000
# 17    18.000000
# 18    19.000000
# 19    20.000000
# 20    21.000000
# 21    22.000000
# 22    23.000000
# 23    24.000000
# 24    25.000000
# 25    26.000000
# 26    27.000000
# 27    28.000000
# 28    29.000000
# 29    30.000000
# Name: Tech ID, dtype: float64

# %%
df.fillna(x)
# Out:
#                  Name  projects-done    Tech ID                  Role  \
# 0    Arshia Chandarki       2.000000   1.000000       Project Manager
# 1     Nazia Chandarki       2.000000   2.000000        UI/UX Designer
# 2         Ayesha Khan       2.000000   3.000000        UI/UX Designer
# 3       Ayushi Gautam       2.000000   4.000000  Cybersecurity Intern
# 4     Sakshi Chudekar       2.000000   5.000000       Project Manager
# 5      Shrawani Botre       2.000000  15.928571     Backend Developer
# 6         Ketan Butta       2.000000   7.000000     Backend Developer
# 7       Tanmay Shinde       2.000000   8.000000        UI/UX Designer
# 8       Jannat Shaikh       2.000000   9.000000     Backend Developer
# 9       Tauhid Shaikh       2.000000  10.000000           AI Engineer
# 10      Pratik Palkar       2.000000  11.000000  Cybersecurity Intern
# 11  Kruthika Janvekar       2.000000  12.000000           AI Engineer
# ...

# %%
df2 = df.copy()

# %%
for col in df.columns:
    if col in df2.columns and df2[col].isnull().any():
        df2[col] = df2[col].fillna(x)  # Fill NaN values with 'x'
print(df2)
# Out:
#                  Name  projects-done    Tech ID                  Role  \
# 0    Arshia Chandarki       2.000000   1.000000       Project Manager
# 1     Nazia Chandarki       2.000000   2.000000        UI/UX Designer
# 2         Ayesha Khan       2.000000   3.000000        UI/UX Designer
# 3       Ayushi Gautam       2.000000   4.000000  Cybersecurity Intern
# 4     Sakshi Chudekar       2.000000   5.000000       Project Manager
# 5      Shrawani Botre       2.000000  15.928571     Backend Developer
# 6         Ketan Butta       2.000000   7.000000     Backend Developer
# 7       Tanmay Shinde       2.000000   8.000000        UI/UX Designer
# 8       Jannat Shaikh       2.000000   9.000000     Backend Developer
# 9       Tauhid Shaikh       2.000000  10.000000           AI Engineer
# 10      Pratik Palkar       2.000000  11.000000  Cybersecurity Intern
# 11  Kruthika Janvekar       2.000000  12.000000           AI Engineer
# ...
