# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv('BostonHousing.csv')
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
x=df.drop('medv',axis = 1)

#output data
y=df['medv']

# %%
x.shape
# Out:
# (333, 14)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.25)

# %%
x_train
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 164  241  0.11329  30.0   4.93     0  0.428  6.897  54.3   6.3361    6  300
# 233  353  0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4  411
# 208  312  0.79041   0.0   9.90     0  0.544  6.122  52.8   2.6403    4  304
# 5     11  0.22489  12.5   7.87     0  0.524  6.377  94.3   6.3467    5  311
# 33    54  0.04981  21.0   5.64     0  0.439  5.998  21.4   6.8147    4  243
# ..   ...      ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 323  491  0.20746   0.0  27.74     0  0.609  5.093  98.0   1.8226    4  711
# 192  287  0.01965  80.0   1.76     0  0.385  6.230  31.5   9.0892    1  241
# 117  172  2.31390   0.0  19.58     0  0.605  5.880  97.3   2.3887    5  403
# 47    71  0.08826   0.0  10.81     0  0.413  6.417   6.6   5.2873    4  305
# 172  252  0.21409  22.0   5.86     0  0.431  6.438   8.9   7.3967    7  330
#
#      ptratio   black  lstat
# 164     16.6  391.25  11.38
# 233     18.3  392.33   7.79
# 208     18.4  396.90   5.98
# 5       15.2  392.52  20.45
# 33      16.8  396.90   8.43
# ..       ...     ...    ...
# 323     20.1  318.43  29.68
# 192     18.2  341.60  12.93
# 117     14.7  348.13  12.03
# 47      19.2  383.73   6.72
# 172     19.1  377.07   3.59
#
# [249 rows x 14 columns]

# %%
x_train.shape
# Out:
# (249, 14)

# %%
x_test.shape
# Out:
# (84, 14)

# %% [markdown]
# Linear Regression

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-6.12844707e-03, -1.54899766e-01,  3.80071276e-02,  9.58827592e-02,
#         4.07258239e+00, -1.91042930e+01,  3.60152381e+00, -2.46876893e-03,
#        -1.53527716e+00,  3.88028612e-01, -1.02470284e-02, -7.89672272e-01,
#         9.68639910e-03, -6.78525376e-01])

# %%
regressor.intercept_
# Out:
# np.float64(36.98051243114213)

# %% [markdown]
# Predictions

# %%
y_pred=regressor.predict(x_test)
y_pred.shape
# Out:
# (84,)

# %%
result=pd.DataFrame({'Actual':y_test,'Producted':y_pred})
result
# Out:
#      Actual  Producted
# 56     22.9  25.898792
# 54     28.0  29.532711
# 276    11.0  13.985537
# 101    15.4  13.512568
# 59     22.5  22.180846
# ..      ...        ...
# 222    19.5  19.449101
# 200    26.4  28.092629
# 253     8.8   1.690877
# 256    11.5  14.439192
# 327    18.3  17.329104
#
# [84 rows x 2 columns]

# %%
residual_error=abs(y_test-y_pred)
residual_error
# Out:
# 56     2.998792
# 54     1.532711
# 276    2.985537
# 101    1.887432
# 59     0.319154
#          ...
# 222    0.050899
# 200    1.692629
# 253    7.109123
# 256    2.939192
# 327    0.970896
# Name: medv, Length: 84, dtype: float64

# %% [markdown]
# MEAN ABSOLUTE ERROR

# %%
sum(residual_error)/len(residual_error)
# Out:
# 3.466826233616042

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_pred,y_test)
# Out:
# 3.4668262336160414

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.18976207581581325

# %%
regressor.score(x_test,y_test)
# Out:
# 0.6790264853292796

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6790264853292796
